# %% [markdown]
# # **Data Visualization - Python - Plotly**
#
# Multiple Line Plot
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1sVP0X-FdEHW1e5gd8Mo8NNpKQvVz8fdW?usp=sharing)
#
# *Oleh : Sinubi*

# %% [markdown]
# ## Persiapan

# %%
# Import Packages/Libraries yang diperlukan
import numpy as np
import pandas as pd
import plotly
import plotly.express as px
import gdown

# %%
# Menampilkan Versi Packages yang digunakan
print("Versi Numpy      : ", np.__version__)
print("Versi Pandas     : ", pd.__version__)
print("Versi Plotly     : ", plotly.__version__)
print("Versi Gdown      : ", gdown.__version__)
# Out:
# Versi Numpy      :  1.23.5
# Versi Pandas     :  1.5.3
# Versi Plotly     :  5.15.0
# Versi Gdown      :  4.6.6

# %%
# Download Dataset Sinubi
gdown.download_folder("https://drive.google.com/drive/folders/1d0O3AuXl4z8VSj75v6WWuaxtUWXnmSYB?usp=sharing")
# Out:
# Retrieving folder list
# Processing file 1Z1oDLjOAedliOGfI_zRiV9UgqXUC605G Dataset SJ 01.xlsx
# Processing file 1gme7jjukWjJrfeKG01aBBx8CTS3cHxOu Dataset SJ 02.xlsx
# Building directory structure completed
# Retrieving folder list completed
# Building directory structure
# Downloading...
# From: https://drive.google.com/uc?id=1Z1oDLjOAedliOGfI_zRiV9UgqXUC605G
# To: /content/Sinubi's Journey/Dataset SJ 01.xlsx
# 100%|██████████| 12.2k/12.2k [00:00<00:00, 15.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1gme7jjukWjJrfeKG01aBBx8CTS3cHxOu
# To: /content/Sinubi's Journey/Dataset SJ 02.xlsx
# 100%|██████████| 12.2k/12.2k [00:00<00:00, 18.4MB/s]
# Download completed
# ["/content/Sinubi's Journey/Dataset SJ 01.xlsx",
#  "/content/Sinubi's Journey/Dataset SJ 02.xlsx"]

# %%
# Import Dataset Sinubi
nama_file = "./Sinubi's Journey/Dataset SJ 02.xlsx"

data_df = pd.read_excel(nama_file, sheet_name='data')

# %%
# Menampilkan Beberapa Data Awal pada Dataset Sinubi
data_df.head()
# Out:
#      Tanggal      Mata Pelajaran  Jumlah Siswa Hadir  Jumlah Siswa Tidak Hadir
# 0 2023-07-05  Pemrograman Python                  30                         0
# 1 2023-07-06  Pemrograman Python                  30                         0
# 2 2023-07-07  Pemrograman Python                  29                         1
# 3 2023-07-08  Pemrograman Python                  30                         0
# 4 2023-07-09  Pemrograman Python                  30                         0

# %%
# Menampilkan Beberapa Data Akhir pada Dataset Sinubi
data_df.tail()
# Out:
#       Tanggal    Mata Pelajaran  Jumlah Siswa Hadir  Jumlah Siswa Tidak Hadir
# 83 2023-08-13  Machine Learning                  27                         3
# 84 2023-08-14  Machine Learning                  26                         4
# 85 2023-08-15  Machine Learning                  27                         3
# 86 2023-08-16  Machine Learning                  28                         2
# 87 2023-08-17  Machine Learning                  28                         2

# %%
# Menampilkan Banyak Baris dan Kolom pada Dataset
data_df.shape
# Out:
# (88, 4)

# %% [markdown]
# Dataset memiliki 4 Kolom dan 88 Baris

# %%
# Membuat Subset Data untuk Mata Pelajaran "Pemrograman Python"
data_df_selected_1 = data_df[data_df['Mata Pelajaran'] == "Pemrograman Python"]
data_df_selected_1.head()
# Out:
#      Tanggal      Mata Pelajaran  Jumlah Siswa Hadir  Jumlah Siswa Tidak Hadir
# 0 2023-07-05  Pemrograman Python                  30                         0
# 1 2023-07-06  Pemrograman Python                  30                         0
# 2 2023-07-07  Pemrograman Python                  29                         1
# 3 2023-07-08  Pemrograman Python                  30                         0
# 4 2023-07-09  Pemrograman Python                  30                         0

# %%
# Membuat Subset Data untuk Mata Pelajaran "Machine Learning"
data_df_selected_2 = data_df[data_df['Mata Pelajaran'] == "Machine Learning"]
data_df_selected_2.head()
# Out:
#       Tanggal    Mata Pelajaran  Jumlah Siswa Hadir  Jumlah Siswa Tidak Hadir
# 44 2023-07-05  Machine Learning                  30                         0
# 45 2023-07-06  Machine Learning                  29                         1
# 46 2023-07-07  Machine Learning                  28                         2
# 47 2023-07-08  Machine Learning                  30                         0
# 48 2023-07-09  Machine Learning                  27                         3

# %% [markdown]
# ## *Multiple Line Plot* dari DataFrame
# sama dengan *Multiple Time-Series Plot*

# %%
# Membuat Multiple Line Plot
fig = px.line(data_df,                                       # DataFrame
              x     = "Tanggal",                             # Variabel untuk X
              y     = "Jumlah Siswa Hadir",                  # Variabel untuk Y
              color = "Mata Pelajaran",                      # Variabel untuk Warna
              title = "Multiple Line Plot dari DataFrame")   # Judul Gambar

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dd52b1ba-fdcf-474f-b602-e5ebfe98a5bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd52b1ba-fdcf-474f-b602-e5ebfe98a5bf")) {                    Plotly.newPlot(                        "dd52b1ba-fdcf-474f-b602-e5ebfe98a5bf",                        [{"hovertemplate":"Mata Pelajaran=Pemrograman Python\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pemrograman Python","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Pemrograman Python","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,30,29,30,30,28,30,29,28,27,28,26,25,29,30,27,30,29,28,29,29,30,28,30,30,29,27,25,26,27,25,29,26,25,24,26,27,28,29,30,29,28,27,28],"yaxis":"y","type":"scatter"},{"hovertemplate":"Mata Pelajaran=Machine Learning\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machine Learning","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,29,28,30,27,28,29,26,25,29,30,27,29,27,27,25,24,23,26,28,28,28,27,26,24,22,23,26,27,30,30,29,28,27,25,28,29,28,30,27,26,27,28,28],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"t ...

# %% [markdown]
# ### Mengubah Warna pada *Multiple Line Plot*

# %%
# Membuat Multiple Line Plot
fig = px.line(data_df,                                              # DataFrame
              x     = "Tanggal",                                    # Variabel untuk X
              y     = "Jumlah Siswa Hadir",                         # Variabel untuk Y
              color = "Mata Pelajaran",                             # Variabel untuk Warna
              title = "Multiple Line Plot dari DataFrame",          # Judul Gambar
              color_discrete_map = {'Pemrograman Python':'green',   # Mapping Warna Line
                                    'Machine Learning':'orange'})   # Mapping Warna Line

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4b427f4d-2002-4b24-aeb6-ff6ff2642b89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b427f4d-2002-4b24-aeb6-ff6ff2642b89")) {                    Plotly.newPlot(                        "4b427f4d-2002-4b24-aeb6-ff6ff2642b89",                        [{"hovertemplate":"Mata Pelajaran=Pemrograman Python\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pemrograman Python","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Pemrograman Python","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,30,29,30,30,28,30,29,28,27,28,26,25,29,30,27,30,29,28,29,29,30,28,30,30,29,27,25,26,27,25,29,26,25,24,26,27,28,29,30,29,28,27,28],"yaxis":"y","type":"scatter"},{"hovertemplate":"Mata Pelajaran=Machine Learning\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","line":{"color":"orange","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machine Learning","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,29,28,30,27,28,29,26,25,29,30,27,29,27,27,25,24,23,26,28,28,28,27,26,24,22,23,26,27,30,30,29,28,27,25,28,29,28,30,27,26,27,28,28],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type ...

# %% [markdown]
# ### Mengubah *Style* dari Line pada *Multiple Line Plot*

# %%
# Membuat Multiple Line Plot
fig = px.line(data_df,                                       # DataFrame
              x     = "Tanggal",                             # Variabel untuk X
              y     = "Jumlah Siswa Hadir",                  # Variabel untuk Y
              color = "Mata Pelajaran",                      # Variabel untuk Warna
              title = "Multiple Line Plot dari DataFrame")   # Judul Gambar

fig.update_traces(line=dict(dash = "dot"))                   # Mengubah Style dari Line

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b0465b80-5a79-4fda-9b0d-8f720aad0f2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0465b80-5a79-4fda-9b0d-8f720aad0f2e")) {                    Plotly.newPlot(                        "b0465b80-5a79-4fda-9b0d-8f720aad0f2e",                        [{"hovertemplate":"Mata Pelajaran=Pemrograman Python\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pemrograman Python","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"Pemrograman Python","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,30,29,30,30,28,30,29,28,27,28,26,25,29,30,27,30,29,28,29,29,30,28,30,30,29,27,25,26,27,25,29,26,25,24,26,27,28,29,30,29,28,27,28],"yaxis":"y","type":"scatter"},{"hovertemplate":"Mata Pelajaran=Machine Learning\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","line":{"color":"#EF553B","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machine Learning","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,29,28,30,27,28,29,26,25,29,30,27,29,27,27,25,24,23,26,28,28,28,27,26,24,22,23,26,27,30,30,29,28,27,25,28,29,28,30,27,26,27,28,28],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type" ...

# %% [markdown]
# ### Mengubah Bentuk *Marker* pada *Multiple Line Plot*

# %%
# Membuat Multiple Line Plot
fig = px.line(data_df,                                       # DataFrame
              x     = "Tanggal",                             # Variabel untuk X
              y     = "Jumlah Siswa Hadir",                  # Variabel untuk Y
              color = "Mata Pelajaran",                      # Variabel untuk Warna
              title = "Multiple Line Plot dari DataFrame",   # Judul Gambar
              markers = True)

fig.update_traces(marker=dict(symbol = "square"))            # Mengubah Bentuk Marker

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1905e90f-8466-4d33-b840-87fe066e5d94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1905e90f-8466-4d33-b840-87fe066e5d94")) {                    Plotly.newPlot(                        "1905e90f-8466-4d33-b840-87fe066e5d94",                        [{"hovertemplate":"Mata Pelajaran=Pemrograman Python\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pemrograman Python","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"square"},"mode":"markers+lines","name":"Pemrograman Python","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,30,29,30,30,28,30,29,28,27,28,26,25,29,30,27,30,29,28,29,29,30,28,30,30,29,27,25,26,27,25,29,26,25,24,26,27,28,29,30,29,28,27,28],"yaxis":"y","type":"scatter"},{"hovertemplate":"Mata Pelajaran=Machine Learning\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"square"},"mode":"markers+lines","name":"Machine Learning","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,29,28,30,27,28,29,26,25,29,30,27,29,27,27,25,24,23,26,28,28,28,27,26,24,22,23,26,27,30,30,29,28,27,25,28,29,28,30,27,26,27,28,28],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}]," ...

# %% [markdown]
# ### Mengubah Ukuran *Marker* pada *Multiple Line Plot*

# %%
# Membuat Multiple Line Plot
fig = px.line(data_df,                                       # DataFrame
              x     = "Tanggal",                             # Variabel untuk X
              y     = "Jumlah Siswa Hadir",                  # Variabel untuk Y
              color = "Mata Pelajaran",                      # Variabel untuk Warna
              title = "Multiple Line Plot dari DataFrame",   # Judul Gambar
              markers = True)

fig.update_traces(marker=dict(size = 10))                    # Mengubah Ukuran Marker

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e2c93a5c-90f3-4e17-abb9-24caaa03642b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2c93a5c-90f3-4e17-abb9-24caaa03642b")) {                    Plotly.newPlot(                        "e2c93a5c-90f3-4e17-abb9-24caaa03642b",                        [{"hovertemplate":"Mata Pelajaran=Pemrograman Python\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pemrograman Python","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines","name":"Pemrograman Python","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,30,29,30,30,28,30,29,28,27,28,26,25,29,30,27,30,29,28,29,29,30,28,30,30,29,27,25,26,27,25,29,26,25,24,26,27,28,29,30,29,28,27,28],"yaxis":"y","type":"scatter"},{"hovertemplate":"Mata Pelajaran=Machine Learning\u003cbr\u003eTanggal=%{x}\u003cbr\u003eJumlah Siswa Hadir=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines","name":"Machine Learning","orientation":"v","showlegend":true,"x":["2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00"],"xaxis":"x","y":[30,29,28,30,27,28,29,26,25,29,30,27,29,27,27,25,24,23,26,28,28,28,27,26,24,22,23,26,27,30,30,29,28,27,25,28,29,28,30,27,26,27,28,28],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"], ...

# %% [markdown]
# # Referensi Eksternal
#
# *   https://plotly.com/python/line-charts/
# *   https://plotly.com/python-api-reference/generated/plotly.express.line
# *   https://www.geeksforgeeks.org/line-chart-using-plotly-in-python/
# *   https://python-charts.com/evolution/line-chart-plotly/
# *   https://www.tutorialspoint.com/line-chart-using-plotly-in-python
# *   https://community.sisense.com/t5/knowledge/changing-line-styling-plot-ly-python-and-r/ta-p/9386
